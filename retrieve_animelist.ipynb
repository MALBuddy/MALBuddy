# %%
import requests
import json
import secrets
import pandas as pd
from refresh_token import refresh_token

CLIENT_ID = "b86965f2d19d8cb2e587519170794328"
CLIENT_SECRET = "fb968c74ca8f6022207bbd052006dce0af3cbc5583a97391142e3dd8bbc7933c"

# %%
token = refresh_token("token.json",CLIENT_ID, CLIENT_SECRET)

# %%
at = token['access_token']

# %% [markdown]
# # Retrieve User Animelist

# %%
at= "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6ImRhNDU2NDUzOTBkZmE4NmVkYTE2M2RmYTg4M2U1OGQyM2NmZDdjZGJjODk2YTQ1NmRlNTk4Nzg5ZWU3MGYxNzk1YTgxMjhhNjc1OWU2YTllIn0..hVCpCGjNr518Vp3A54Rc2ZdXS81GyVRl3Gt0JT4D-HsvFVCTqq11HMVuF7Jfqftt0oERlxEVzFexY40m4ykyoBjESLsGfjnOjKNGBqSMD39li-pvt12GOuhzsidgwAZyMUvJ3lZko5VM3tRfaZt6PwIAIbAEzSQLGsgDrza06BYPqWduPUMOizSXE-WiGTyxroBHibZe1gBI5o72qt118S1qAXnS-2eJn_vrblGEvSRwNNxrkqiWKUYp9B-zV63f4E2aXsmqFI7JTZ3rVtQweY9IZeaV3uBtvKucnEGqQvqQO4U-WdP1-DdbNaLStEeFEWR6-21ysqaXuFonhvpNlw"

# %%
url = "https://api.myanimelist.net/v2/users/chocopieeater/animelist?fields=list_status&limit=500"

# %%
anilist= requests.get(url, headers = {"Authorization" : f"Bearer {at}"})#.json()

# %%
anilist.ok
# Out:
# True

# %%
mal = anilist['data']

# %%
mal_df = pd.DataFrame()
data = []
for anime in mal:
    dictionary = anime['node']
    dictionary.update(anime['list_status'])
    data.append(dictionary)
    
mal_df = pd.DataFrame(data)

# %%
mal_df
# Out:
#         id                                              title  \
# 0    41457                                                 86
# 1    22199                                     Akame ga Kill!
# 2    41433                                      Akudama Drive
# 3    22729                                       Aldnoah.Zero
# 4    27655                            Aldnoah.Zero 2nd Season
# ..     ...                                                ...
# 210  39617                   Yakusoku no Neverland 2nd Season
# 211  32615                                        Youjo Senki
# 212  49233                                     Youjo Senki II
# 213  37055                                  Youjo Senki Movie
# 214  35507  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...
#
#                                           main_picture         status  score  \
# 0    {'medium': 'https://api-cdn.myanimelist.net/im...        dropped      0
# ...

# %%
labels = ['main_picture', 'num_episodes_watched', 'finish_date', 'start_date', 'is_rewatching', 'updated_at']
ratings = mal_df.drop(labels,axis=1)
ratings
# Out:
#         id                                              title         status  \
# 0    41457                                                 86        dropped
# 1    22199                                     Akame ga Kill!      completed
# 2    41433                                      Akudama Drive        dropped
# 3    22729                                       Aldnoah.Zero      completed
# 4    27655                            Aldnoah.Zero 2nd Season        dropped
# ..     ...                                                ...            ...
# 210  39617                   Yakusoku no Neverland 2nd Season        dropped
# 211  32615                                        Youjo Senki      completed
# 212  49233                                     Youjo Senki II  plan_to_watch
# 213  37055                                  Youjo Senki Movie      completed
# 214  35507  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...      completed
#
#      score
# 0        0
# 1        8
# ...

# %% [markdown]
# # Next step -> Gather peer data from anime

# %% [markdown]
# ## Web scrape users who have seen the anime
